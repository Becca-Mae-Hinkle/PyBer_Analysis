# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
# Out:
# -----------------------------------------------------------
# ModuleNotFoundError       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1860/2233703332.py in <module>
#       1 # Dependencies
# ----> 2 import matplotlib.pyplot as plt
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !conda list
# Out:
# # packages in environment at C:\Users\Becca\anaconda3\envs\PythonData:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2021.11                  py37_0
# alabaster                 0.7.12                   py37_0
# anaconda                  custom                   py37_1
# anaconda-client           1.9.0            py37haa95532_0
# anaconda-project          0.10.2             pyhd3eb1b0_0
# anyio                     2.2.0            py37haa95532_2
# appdirs                   1.4.4              pyhd3eb1b0_0
# argcomplete               1.12.3             pyhd3eb1b0_0
# argh                      0.26.2                   py37_0
# argon2-cffi               20.1.0           py37h2bbff1b_1
# arrow                     0.13.1                   py37_0
# asn1crypto                1.4.0                      py_0
# astroid                   2.6.6            py37haa95532_0
# astropy                   4.3.1            py37hc7d831d_0
# ...
